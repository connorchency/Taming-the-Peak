# %%
import pylab as pl
import pandas as pd
import numpy as np
# %pylab inline

import os
import csv
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
M_I_BR = pd.read_csv('ACS_14_5YR_B19013_with_annBR.csv')
M_I_BX = pd.read_csv('ACS_14_5YR_B19013_with_annBX.csv')
M_I_MH = pd.read_csv('ACS_14_5YR_B19013_with_annMH.csv')
M_I_QU = pd.read_csv('ACS_14_5YR_B19013_with_annQU.csv')
M_I_ST = pd.read_csv('ACS_14_5YR_B19013_with_annST.csv')
joined = [M_I_BR, M_I_BX, M_I_MH, M_I_QU, M_I_ST]
all_income = pd.concat(joined)
all_income.head()
# Out:
#                  GEO.id      GEO.id2  \
# 0                    Id          Id2
# 1  1400000US36047000100  36047000100
# 2  1400000US36047000200  36047000200
# 3  1400000US36047000301  36047000301
# 4  1400000US36047000501  36047000501
#
#                            GEO.display-label  \
# 0                                  Geography
# 1     Census Tract 1, Kings County, New York
# 2     Census Tract 2, Kings County, New York
# 3  Census Tract 3.01, Kings County, New York
# 4  Census Tract 5.01, Kings County, New York
#
#                                            HD01_VD01  \
# 0  Estimate; Median household income in the past ...
# 1                                              80318
# 2                                              35500
# 3                                             105509
# 4                                             110625
#
#                                            HD02_VD01
# 0  Margin of Error; Median household income in th...
# ...

# %%
all_income.describe()
# Out:
#        GEO.id GEO.id2 GEO.display-label HD01_VD01 HD02_VD01
# count    2172    2172              2172      2172      2172
# unique   2168    2168              2168      2012      2017
# top        Id     Id2         Geography         -        **
# freq        5       5                 5        56        56

# %%
all_income
# Out:
#                    GEO.id      GEO.id2  \
# 0                      Id          Id2
# 1    1400000US36047000100  36047000100
# 2    1400000US36047000200  36047000200
# 3    1400000US36047000301  36047000301
# 4    1400000US36047000501  36047000501
# 5    1400000US36047000502  36047000502
# 6    1400000US36047000700  36047000700
# 7    1400000US36047000900  36047000900
# 8    1400000US36047001100  36047001100
# 9    1400000US36047001300  36047001300
# 10   1400000US36047001500  36047001500
# 11   1400000US36047001800  36047001800
# 12   1400000US36047002000  36047002000
# 13   1400000US36047002100  36047002100
# 14   1400000US36047002200  36047002200
# 15   1400000US36047002300  36047002300
# 16   1400000US36047002901  36047002901
# 17   1400000US36047003000  36047003000
# 18   1400000US36047003100  36047003100
# 19   1400000US36047003300  36047003300
# 20   1400000US36047003400  36047003400
# 21   1400000US36047003500  36047003500
# 22   1400000US36047003600  36047003600
# ...

# %%
all_income.reset_index(inplace=True)
all_income
# Out:
#       index                GEO.id      GEO.id2  \
# 0         0                    Id          Id2
# 1         1  1400000US36047000100  36047000100
# 2         2  1400000US36047000200  36047000200
# 3         3  1400000US36047000301  36047000301
# 4         4  1400000US36047000501  36047000501
# 5         5  1400000US36047000502  36047000502
# 6         6  1400000US36047000700  36047000700
# 7         7  1400000US36047000900  36047000900
# 8         8  1400000US36047001100  36047001100
# 9         9  1400000US36047001300  36047001300
# 10       10  1400000US36047001500  36047001500
# 11       11  1400000US36047001800  36047001800
# 12       12  1400000US36047002000  36047002000
# 13       13  1400000US36047002100  36047002100
# 14       14  1400000US36047002200  36047002200
# 15       15  1400000US36047002300  36047002300
# 16       16  1400000US36047002901  36047002901
# 17       17  1400000US36047003000  36047003000
# 18       18  1400000US36047003100  36047003100
# ...

# %%
all_income.dropna(inplace=True)

# %%
all_income.describe()
# Out:
#              index
# count  2172.000000
# mean    285.178177
# std     205.945132
# min       0.000000
# 25%     108.000000
# 50%     243.000000
# 75%     444.000000
# max     761.000000
