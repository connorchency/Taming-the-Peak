# %%
from __future__ import print_function
import pandas as pd, os, numpy as np
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim()
def getzip(a):
   location = geolocator.reverse(a)
   return (location.raw['address']['postcode'])

# %%
weather = pd.read_csv("Weather Data.csv")

# %%
weather = weather[weather['LATITUDE'] != 'unknown']
weather = weather[weather['LONGITUDE'] != 'unknown']
weather.head()
# Out:
#              STATION                                STATION_NAME ELEVATION  \
# 0  GHCND:USW00014732                    LA GUARDIA AIRPORT NY US       3.4
# 1  GHCND:USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT NJ US       2.1
# 2  GHCND:US1NYNS0006                       LEVITTOWN 0.2 E NY US      27.1
# 3  GHCND:US1NYNS0007                     FLORAL PARK 0.4 W NY US      24.1
# 4  GHCND:US1NJMS0016                       KINNELON 1.4 SE NJ US     262.4
# 5  GHCND:US1NJMN0035                  SHREWSBURY TWP 2.1 S NJ US      19.2
# 6  GHCND:US1NJMS0011                        BOONTON 0.6 NW NJ US     188.7
# 7  GHCND:US1NJMN0032                      FAIR HAVEN 0.4 E NJ US       9.8
# 8  GHCND:US1NJMN0033                  MONMOUTH BEACH 0.5 S NJ US       5.8
# 9  GHCND:USW00094741                     TETERBORO AIRPORT NJ US       2.7
#
#    LATITUDE  LONGITUDE      DATE    MDPR  Time of Observation    MDSF  \
# 0  40.77944  -73.88028  20100101 -9999.0                 9999 -9999.0
# 1   40.6825  -74.16944  20100101 -9999.0                 9999 -9999.0
# 2   40.7245   -73.5086  20100101 -9999.0                 9999 -9999.0
# 3    40.723    -73.711  20100101 -9999.0                 9999 -9999.0
# 4    40.969    -74.371  20100101 -9999.0                 9999 -9999.0
# 5   40.2837   -74.0677  20100101 -9999.0                 9999 -9999.0
# 6   40.9096   -74.4141  20100101 -9999.0                 9999 -9999.0
# 7   40.3627   -74.0312  20100101 -9999.0                 9999 -9999.0
# 8   40.3292   -73.9883  20100101 -9999.0                 9999 -9999.0
# 9     40.85  -74.06139  20100101 -9999.0                 9999 -9999.0
#
#    Time of Observation.1          ...            PGTM  Measurement Flag.11  \
# 0                   9999          ...            2327
# 1                   9999          ...            2253
# 2                   9999          ...           -9999
# 3                   9999          ...           -9999
# 4                   9999          ...           -9999
# 5                   9999          ...           -9999
# 6                   9999          ...           -9999
# 7                   9999          ...           -9999
# 8                   9999          ...           -9999
# 9                   9999          ...            2334
#
#    Quality Flag.13 Source Flag.14 Time of Observation.17  FMTM  \
# 0                               W                   9999  2337
# 1                               W                   9999  2254
# 2                                                   9999 -9999
# 3                                                   9999 -9999
# 4                                                   9999 -9999
# 5                                                   9999 -9999
# 6                                                   9999 -9999
# 7                                                   9999 -9999
# 8                                                   9999 -9999
# 9                               W                   9999 -9999
#
#    Measurement Flag.12  Quality Flag.14 Source Flag.15 Time of Observation.18
# 0                                                    X                   9999
# 1                                                    X                   9999
# 2                                                                        9999
# 3                                                                        9999
# 4                                                                        9999
# 5                                                                        9999
# 6                                                                        9999
# 7                                                                        9999
# 8                                                                        9999
# 9                                                                        9999
#
# [10 rows x 88 columns]

# %%
coord = weather[['LATITUDE', 'LONGITUDE']]
coord = pd.DataFrame.drop_duplicates(coord)
zips = []
for i in range(len(coord)):
    try:
         zips.append(getzip(str(str(coord['LATITUDE'][i]) + "," + str(coord['LONGITUDE'][i]))))
    except KeyError: 
        zips.append('NA')
coord['ZipCode'] = zips

# %%
print(coord)
# Out:
#         LATITUDE  LONGITUDE ZipCode
# 0       40.77944  -73.88028   11371
# 1        40.6825  -74.16944   07201
# 2        40.7245   -73.5086   11756
# 3         40.723    -73.711   11001
# 4         40.969    -74.371   07405
# 5        40.2837   -74.0677   07724
# 6        40.9096   -74.4141   07005
# 7        40.3627   -74.0312   07704
# 8        40.3292   -73.9883   07750
# 9          40.85  -74.06139   07608
# 10       41.0624   -73.7046   10604
# 11       41.0825  -73.63861   06831
# 12        40.427   -74.1071   07718
# 13      40.66694  -74.32306   07027
# 14      40.74361  -74.35389   07078
# 15       40.8656   -74.3851   07054
# 16       40.3034     -74.04   07724
# 17       40.3204   -74.1927   07722
# 18      40.73278  -73.61833   11514
# 19      40.73417  -73.41694   11735
# 20       41.0191   -74.2334   07436
# 21       40.9412   -74.2267   07470
# 22       40.9519   -74.1577   07506
# 23       40.3622   -74.0833   07701
# 24        40.748   -74.1518   07029
# 25       40.8796    -74.227   07424
# 26       40.9436   -74.1523   07506
# 27      41.00722  -73.83444   10502
# 28      40.63861  -73.76222      NA
# 29        40.655  -73.50528   11793
# ...          ...        ...     ...
# 81979     40.785   -74.1885      NA
# 81993    40.8615   -74.2775      NA
# 82009    40.7294   -74.3719      NA
# 82025    40.6846   -73.9867      NA
# 82045    40.8305   -74.2539      NA
# 82049    40.7924   -74.4546      NA
# 82093    40.4565   -74.2994      NA
# 86301    40.6023   -74.3102      NA
# 86529    40.4057   -74.2549      NA
# 87271    40.8557   -74.2356      NA
# 91583    40.7535   -74.4428      NA
# 91617    40.7413   -74.4395      NA
# 94740    40.4562   -74.2413      NA
# 98347    40.4562   -74.2413      NA
# 98355    40.4057   -74.2549      NA
# 98366    40.6023   -74.3102      NA
# 98370    40.8557   -74.2356      NA
# 98428    40.7535   -74.4428      NA
# 98458    40.7413   -74.4395      NA
# 101106   41.0202   -74.3289      NA
# 101621   40.7524   -74.4297      NA
# 110254   40.6623    -73.678      NA
# 114397   40.3204   -74.1927      NA
# 116432   40.9005   -74.4164      NA
# 119469   40.2754    -74.006      NA
# 124008   40.7279   -73.4341   07940
# 133827   40.7792     -73.88      NA
# 133829   40.6825   -74.1694      NA
# 133876   40.7889   -73.9669      NA
# 134387   40.6386   -73.7622      NA
#
# [241 rows x 3 columns]

# %%
pd.unique(zips)
# Out:
# array([u'11371', u'07201', u'11756', u'11001', u'07405', u'07724',
#        u'07005', u'07704', u'07750', u'07608', u'10604', u'06831',
#        u'07718', u'07027', u'07078', u'07054', u'07722', u'11514',
#        u'11735', u'07436', u'07470', u'07506', u'07701', u'07029',
#        u'07424', u'10502', 'NA', u'11793', u'07663', u'07670', u'07446',
#        u'07980', u'07080', u'11721', u'11572', u'07031', u'07452',
#        u'07650', u'10024', u'07090', u'10462', u'07004', u'07922',
#        u'07432', u'07032', u'10308', u'07940'], dtype=object)
