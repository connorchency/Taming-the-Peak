# %%
from __future__ import print_function
import pandas as pd, os, numpy as np, json, urllib

# %%
weather = pd.read_csv("Weather Data.csv", low_memory=False)

# %%
weather = weather[weather['LATITUDE'] != 'unknown']
weather = weather[weather['LONGITUDE'] != 'unknown']
weather.head()
# Out:
#              STATION                                STATION_NAME ELEVATION  \
# 0  GHCND:USW00014732                    LA GUARDIA AIRPORT NY US       3.4
# 1  GHCND:USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT NJ US       2.1
# 2  GHCND:US1NYNS0006                       LEVITTOWN 0.2 E NY US      27.1
# 3  GHCND:US1NYNS0007                     FLORAL PARK 0.4 W NY US      24.1
# 4  GHCND:US1NJMS0016                       KINNELON 1.4 SE NJ US     262.4
#
#    LATITUDE  LONGITUDE      DATE    MDPR  Time of Observation    MDSF  \
# 0  40.77944  -73.88028  20100101 -9999.0                 9999 -9999.0
# 1   40.6825  -74.16944  20100101 -9999.0                 9999 -9999.0
# 2   40.7245   -73.5086  20100101 -9999.0                 9999 -9999.0
# 3    40.723    -73.711  20100101 -9999.0                 9999 -9999.0
# 4    40.969    -74.371  20100101 -9999.0                 9999 -9999.0
#
#    Time of Observation.1          ...            PGTM  Measurement Flag.11  \
# 0                   9999          ...            2327
# 1                   9999          ...            2253
# 2                   9999          ...           -9999
# 3                   9999          ...           -9999
# 4                   9999          ...           -9999
#
#    Quality Flag.13 Source Flag.14 Time of Observation.17  FMTM  \
# 0                               W                   9999  2337
# 1                               W                   9999  2254
# 2                                                   9999 -9999
# 3                                                   9999 -9999
# 4                                                   9999 -9999
#
#    Measurement Flag.12  Quality Flag.14 Source Flag.15 Time of Observation.18
# 0                                                    X                   9999
# 1                                                    X                   9999
# 2                                                                        9999
# 3                                                                        9999
# 4                                                                        9999
#
# [5 rows x 88 columns]

# %%
coord = weather[['LATITUDE', 'LONGITUDE']]
coord = pd.DataFrame.drop_duplicates(coord)
lat = np.array(coord['LATITUDE']).astype(float)
lng = np.array(coord['LONGITUDE']).astype(float)
zips = []
for i in range(len(coord)):
    try:
        data = json.load(urllib.urlopen('https://maps.googleapis.com/maps/api/geocode/json?latlng=' + str(lat[i]) + ','+ str(lng[i])+ '&key=AIzaSyB-TYwQ3fKTlOH8Srz5Jo0YVMO793rHPXQ'))
        zips.append(data["results"][0]['address_components'][-1]['long_name'])
    except KeyError:
        zips.append(np.nan)
        print('the {}th iteration is not successful, return nan value'.format(i))
coord['ZipCode'] = zips

# %%
zips
# Out:
# [u'11369',
#  u'07201',
#  u'4602',
#  u'2607',
#  u'3147',
#  u'1423',
#  u'1219',
#  u'3548',
#  u'1052',
#  u'1028',
#  u'1110',
#  u'3408',
#  u'1210',
#  u'1547',
#  u'07078',
#  u'2104',
#  u'2307',
#  u'1247',
#  u'4716',
#  u'11735',
#  u'3207',
#  u'2932',
#  u'07506',
#  u'5862',
#  u'1514',
#  u'1534',
#  u'07506',
#  u'10502',
#  u'11430',
#  u'4341',
#  u'4631',
#  u'2616',
#  u'1946',
#  u'5240',
#  u'1512',
#  u'4419',
#  u'1704',
#  u'4538',
#  u'5727',
#  u'3510',
#  u'1134',
#  u'1504',
#  u'10024',
#  u'1215',
#  u'07732',
#  u'4923',
#  u'3455',
#  u'2637',
#  u'1550',
#  u'2910',
#  u'3238',
#  u'07940',
#  u'1958',
#  u'1932',
#  u'10954',
#  u'5566',
#  u'07465',
#  u'3104',
#  u'1408',
#  u'07641',
#  u'10603',
#  u'2221',
#  u'1112',
#  u'07060',
#  u'11560',
#  u'2218',
#  u'3526',
#  u'4359',
#  u'3068',
#  u'1602',
#  u'1035',
#  u'2409',
#  u'2008',
#  u'4013',
#  u'3216',
#  u'3319',
#  u'11379',
#  u'1111',
#  u'1750',
#  u'1766',
#  u'1315',
#  u'08859',
#  u'1433',
#  u'2606',
#  u'3639',
#  u'1839',
#  u'5521',
#  u'2553',
#  u'2961',
#  u'07078',
#  u'10462',
#  u'2807',
#  u'1828',
#  u'4341',
#  u'1409',
#  u'1515',
#  u'1220',
#  u'10502',
#  u'1616',
#  u'3408',
#  u'07060',
#  u'2308',
#  u'4923',
#  u'2035',
#  u'1550',
#  u'07960',
#  u'9602',
#  u'3351',
#  u'2813',
#  u'2023',
#  u'5045',
#  u'07040',
#  u'1905',
#  u'6532',
#  u'1407',
#  u'5740',
#  u'07960',
#  u'1408',
#  u'1207',
#  u'1420',
#  u'2115',
#  u'3678',
#  u'5136',
#  u'08859',
#  u'11217',
#  u'2104',
#  u'1823',
#  u'3707',
#  u'1423',
#  u'07940',
#  u'3007',
#  u'08879',
#  u'1420',
#  u'2411',
#  u'2038',
#  u'1319',
#  u'8003',
#  u'4308',
#  u'11369',
#  u'07201',
#  u'7659',
#  u'11430']

# %%
pd.unique(zips)
# Out:
# array([u'11369', u'07201', u'4602', u'2607', u'3147', u'1423', u'1219',
#        u'3548', u'1052', u'1028', u'1110', u'3408', u'1210', u'1547',
#        u'07078', u'2104', u'2307', u'1247', u'4716', u'11735', u'3207',
#        u'2932', u'07506', u'5862', u'1514', u'1534', u'10502', u'11430',
#        u'4341', u'4631', u'2616', u'1946', u'5240', u'1512', u'4419',
#        u'1704', u'4538', u'5727', u'3510', u'1134', u'1504', u'10024',
#        u'1215', u'07732', u'4923', u'3455', u'2637', u'1550', u'2910',
#        u'3238', u'07940', u'1958', u'1932', u'10954', u'5566', u'07465',
#        u'3104', u'1408', u'07641', u'10603', u'2221', u'1112', u'07060',
#        u'11560', u'2218', u'3526', u'4359', u'3068', u'1602', u'1035',
#        u'2409', u'2008', u'4013', u'3216', u'3319', u'11379', u'1111',
#        u'1750', u'1766', u'1315', u'08859', u'1433', u'2606', u'3639',
#        u'1839', u'5521', u'2553', u'2961', u'10462', u'2807', u'1828',
#        u'1409', u'1515', u'1220', u'1616', u'2308', u'2035', u'07960',
#        u'9602', u'3351', u'2813', u'2023', u'5045', u'07040', u'1905',
#        u'6532', u'1407', u'5740', u'1207', u'1420', u'2115', u'3678',
#        u'5136', u'11217', u'1823', u'3707', u'3007', u'08879', u'2411',
#        u'2038', u'1319', u'8003', u'4308', u'7659'], dtype=object)
